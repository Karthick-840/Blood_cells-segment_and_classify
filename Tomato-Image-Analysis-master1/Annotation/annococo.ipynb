# %%
# %run labelme2coco.py /mnt/Annotations/Images/Training-Large/Train Training-Large/Train --labels labels.txt
# Out:
# Creating dataset: Training-Large/Train
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Train/Be_247.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Train/Ch_194.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Train/Sa_549.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Train/Sa_237.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Train/Ob_068.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Train/Sa_250.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Train/Ch_154.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Train/Sa_326.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Train/Be_128.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Train/Be_213.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Train/CP_019.json
# ...

# %%
# %run labelme2coco.py /mnt/Annotations/Images/Training-Large/Val Training-Large/Val --labels labels.txt
# Out:
# Creating dataset: Training-Large/Val
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Val/CP_020.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Val/Ch_204.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Val/Be_244.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Val/Ob_035.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Val/Sa_384.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Val/Be_440.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Val/Sa_387.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Val/SM_069.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Val/CP_044.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Val/Be_122.json
# Generating dataset from: /mnt/Annotations/Images/Training-Large/Val/Ch_232.json
# ...
