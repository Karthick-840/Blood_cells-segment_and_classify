# %% [markdown]
# # COCO Image Viewer
# This notebook will allow you to view details about a COCO dataset and preview segmentations on annotated images.
# Learn more about it at: http://cocodataset.org/

# %%
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# %%
# Load the dataset json
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = ['blue', 'purple', 'red', 'green', 'orange', 'salmon', 'pink', 'gold',
                       'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                       'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                       'magenta', 'sienna', 'maroon']

        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()

        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()

    def display_info(self):
        print('Dataset Info:')
        print('=============')
        if self.info is None:
            return
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))

        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

    def display_licenses(self):
        print('Licenses:')
        print('=========')

        if self.licenses is None:
            return
        requirements = [['id', int],
                        ['url', str],
                        ['name', str]]
        for license in self.licenses:
            for key, item in license.items():
                print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(
                        req, str(req_type)))
            print('')
        print('')

    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(
                    cat_id, self.categories[cat_id]['name']))
            print('')

    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))

        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))

        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))

        else:
            # image_path = os.path.join(self.image_dir, image['file_name'])
            image_path = "{}/{}".format(self.image_dir, image['file_name'])
            image = PILImage.open(image_path)

        # Calculate the size and adjusted display size
        max_width = 600
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height

        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        bbox_categories = {}
        print('  segmentations ({}):'.format(
            len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(
                            trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height)
                                      * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})

                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1  # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(
                                    full_lines_to_insert * adjusted_ratio)
                                rle_list.append(
                                    {'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})

                            # Insert bottom line
                            rle_list.append(
                                {'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(
                        segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(
                        str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['id']] = polygons_list
            if i < len(self.colors):
                poly_colors[segm['id']] = self.colors[i]
            else:
                poly_colors[segm['id']] = 'white'

            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] +
                           bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['id']] = str(
                bbox_points).lstrip('[').rstrip(']')
            bbox_categories[segm['id']] = self.categories[segm['category_id']]
            # Print details
            print('    {}:{}:{}'.format(
                segm['id'], poly_colors[segm['id']], self.categories[segm['category_id']]))

        # Draw segmentation polygons on image
        html = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(
            image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(
            adjusted_width, adjusted_height)

        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(
                        points, fill_color, stroke_color)

        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(
                        x, y, w, h, fill_color, stroke_color)

        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                x, y = [int(i) for i in points.split()[:2]]
                html += '<text x="{}" y="{}" fill="yellow">{}</text>'.format(
                    x, y, bbox_categories[seg_id]["name"])
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(
                    points, fill_color, stroke_color)

        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html

    def process_info(self):
        self.info = self.coco.get('info')

    def process_licenses(self):
        self.licenses = self.coco.get('licenses')

    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['id']
            super_category = category['supercategory']

            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                # Create a new set with the category id
                self.super_categories[super_category] = {cat_id}
            else:
                self.super_categories[super_category] |= {
                    cat_id}  # Add category id to the set

    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image

    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %%
annotation_path = "/mnt/Annotations/train/annotations.json"
image_dir = "/mnt/Annotations/train"

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
# Out:
# Dataset Info:
# =============
#   description: None
#   url: None
#   version: None
#   year: 2020
#   contributor: None
#   date_created: 2020-09-01 09:44:44.949715
# ERROR: description should be type <class 'str'>
# ERROR: url should be type <class 'str'>
# ERROR: version should be type <class 'str'>
# ERROR: contributor should be type <class 'str'>
#
# Licenses:
# =========
#   url: None
#   id: 1
#   name: None
# ERROR: url should be type <class 'str'>
# ERROR: name should be type <class 'str'>
#
#
# Categories:
# =========
#   super_category: None
#     id 1: Ruler
#     id 2: Tomato Half
#     id 3: Tomato Side
#     id 4: Tomato Top
#     id 5: Tomato Unripe

# %%
for k, v in coco_dataset.images.items():
    print(k, v)
# Out:
# 0 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_247.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 0}
# 1 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_194.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 1}
# 2 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_237.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 2}
# 3 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ob_068.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 3}
# 4 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_154.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 4}
# 5 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_128.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 5}
# 6 {'license': 0, 'url': None, 'file_name': 'JPEGImages/CP_019.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 6}
# 7 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_448.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 7}
# 8 {'license': 0, 'url': None, 'file_name': 'JPEGImages/SM_034.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 8}
# 9 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_132.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 9}
# 10 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_083.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 10}
# 11 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_156.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 11}
# 12 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_085.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 12}
# 13 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_012.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 13}
# 14 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_103.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 14}
# 15 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_456.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 15}
# 16 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ob_028.jpg', 'height': 480, 'width': 640, 'date_captured': None, 'id': 16}
# 17 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_119.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 17}
# 18 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_041.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 18}
# 19 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_502.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 19}
# 20 {'license': 0, 'url': None, 'file_name': 'JPEGImages/CP_033.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 20}
# 21 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_033.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 21}
# 22 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_018.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 22}
# 23 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_447.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 23}
# 24 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_302.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 24}
# 25 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_233.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 25}
# 26 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_473.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 26}
# 27 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_546.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 27}
# 28 {'license': 0, 'url': None, 'file_name': 'JPEGImages/CB_002.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 28}
# 29 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Co_023.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 29}
# 30 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_458.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 30}
# 31 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_203.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 31}
# 32 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_035.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 32}
# 33 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_060.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 33}
# 34 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_002.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 34}
# 35 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_236.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 35}
# 36 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ob_061.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 36}
# 37 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_188.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 37}
# 38 {'license': 0, 'url': None, 'file_name': 'JPEGImages/SM_065.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 38}
# 39 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_167.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 39}
# 40 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ob_067.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 40}
# 41 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_438.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 41}
# 42 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_418.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 42}
# 43 {'license': 0, 'url': None, 'file_name': 'JPEGImages/SM_023.jpg', 'height': 2304, 'width': 2937, 'date_captured': None, 'id': 43}
# 44 {'license': 0, 'url': None, 'file_name': 'JPEGImages/SM_072.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 44}
# 45 {'license': 0, 'url': None, 'file_name': 'JPEGImages/CP_016.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 45}
# 46 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Pe_002.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 46}
# 47 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_146.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 47}
# 48 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_002.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 48}
# 49 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_131.jpg', 'height': 2178, 'width': 3064, 'date_captured': None, 'id': 49}
# 50 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ma_002.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 50}
# 51 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_196.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 51}
# 52 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_197.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 52}
# 53 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_524.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 53}
# 54 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_054.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 54}
# 55 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Ch_001.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 55}
# 56 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Be_428.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 56}
# 57 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_483.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 57}
# 58 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_478.jpg', 'height': 3264, 'width': 4912, 'date_captured': None, 'id': 58}
# 59 {'license': 0, 'url': None, 'file_name': 'JPEGImages/Sa_318.jpg', 'height': 2304, 'width': 3072, 'date_captured': None, 'id': 59}

# %%
html = coco_dataset.display_image(5, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   license: 0
#   url: None
#   file_name: JPEGImages/Be_128.jpg
#   height: 2304
#   width: 3072
#   date_captured: None
#   id: 5
#   segmentations (5):
#     22:blue:{'supercategory': None, 'id': 2, 'name': 'Tomato Half'}
#     23:purple:{'supercategory': None, 'id': 5, 'name': 'Tomato Unripe'}
#     24:red:{'supercategory': None, 'id': 3, 'name': 'Tomato Side'}
#     25:green:{'supercategory': None, 'id': 4, 'name': 'Tomato Top'}
#     26:orange:{'supercategory': None, 'id': 1, 'name': 'Ruler'}
# <div class="container" style="position:relative;"><img src="/mnt/Annotations/train/JPEGImages/Be_128.jpg" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="450.0"><polygon points=" 58 237  70 229  87 222 101 220 120 221 136 223 149 227 159 231 166 238
#  176 249 188 260 195 272 199 284 200 294 197 311 194 325 190 339 183 355
#  173 363 158 372 144 379 129 382  97 383  89 380  74 375  61 366  51 353
#   35 327  29 309  29 291  38 267  46 250" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="428 100 440  93 454  88 474  87 486  88 503  93 514  99 526 107 534 118
#  542 130 546 144 547 156 544 162 539 175 532 195 521 210 507 219 493 223
#  470 225 452 223 433 210 421 198 408 179 404 165 403 146 409 121 421 107" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="256  94 266  87 276  84 287  84 299  86 310  86 324  86 333  88 345  89
#  362  94 370 101 378 114 385 128 385 145 383 163 375 177 365 187 351 196
#  330 203 308 204 288 201 267 193 253 181 244 168 237 147 238 127 244 110" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points=" 96  68 109  63 122  59 139  57 161  58 179  67 190  76 199  91 207 104
#  213 122 214 134 209 154 201 173 193 186 176 195 163 201 142 206 122 206
#  104 198  85 185  71 167  63 148  61 127  66 108  79  88  87  74" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points=" 79 409  78 415  97 417  97 410" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><text x="29" y="220" fill="yellow">Tomato Half</text><polygon points=" 29 220 200 220 200 383  29 383  29 220" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="403" y="87" fill="yellow">Tomato Unripe</text><polygon points="403  87 547  87 547 225 403 225 403  87" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="237" y="84" fill="yellow">Tomato Side</text><polygon points="237  84 386  84 386 204 237 204 237  84" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /><text x="61" y="57" fill="yellow">Tomato Top</text><polygon points=" 61  57 214  57 214 206  61 206  61  57" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0" /><text x="78" y="409" fill="yellow">Ruler</text><polygon points=" 78 409  98 409  98 417  78 417  78 409" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>

# %%
html = coco_dataset.display_image(1, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   license: 0
#   url: None
#   file_name: JPEGImages/Ch_194.jpg
#   height: 2304
#   width: 3072
#   date_captured: None
#   id: 1
#   segmentations (5):
#     4:blue:{'supercategory': None, 'id': 5, 'name': 'Tomato Top'}
#     5:purple:{'supercategory': None, 'id': 4, 'name': 'Tomato Side'}
#     6:red:{'supercategory': None, 'id': 6, 'name': 'Tomato Unripe'}
#     7:green:{'supercategory': None, 'id': 3, 'name': 'Tomato Half'}
#     8:orange:{'supercategory': None, 'id': 2, 'name': 'Ruler'}
# <div class="container" style="position:relative;"><img src="/mnt/Annotations/train/JPEGImages/Ch_194.jpg" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="450.0"><polygon points="139 163 145 161 152 159 160 159 170 159 179 162 188 167 193 173 196 177
#  201 182 205 189 208 197 208 206 207 217 203 225 198 233 191 239 180 245
#  169 248 156 249 144 247 132 241 125 234 118 225 115 212 115 201 117 190
#  122 181 130 172 135 166" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="282 165 289 160 298 157 306 157 324 158 336 160 347 165 356 172 360 182
#  362 188 363 197 361 207 358 216 353 224 346 230 337 235 326 238 319 238
#  312 238 301 235 291 232 283 227 276 219 271 209 270 196 272 181 275 173" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="463 160 473 158 485 156 496 156 505 159 515 164 521 171 527 181 530 187
#  532 197 530 208 528 218 521 225 516 229 511 236 503 243 495 248 487 251
#  475 250 464 248 453 243 442 234 436 225 432 214 431 205 434 189 442 173
#  449 166 458 162" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="137 282 144 280 157 277 168 277 178 279 185 284 193 292 199 304 202 316
#  202 329 200 341 195 351 189 360 182 367 174 371 165 372 156 373 147 374
#  133 371 120 364 111 354 107 342 105 326 110 311 115 302 122 292 129 286" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points=" 21 380  21 390  46 391  47 380" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><text x="115" y="158" fill="yellow">Tomato Top</text><polygon points="115 158 208 158 208 249 115 249 115 158" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="269" y="157" fill="yellow">Tomato Side</text><polygon points="269 157 363 157 363 239 269 239 269 157" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="431" y="156" fill="yellow">Tomato Unripe</text><polygon points="431 156 532 156 532 251 431 251 431 156" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /><text x="105" y="277" fill="yellow">Tomato Half</text><polygon points="105 277 202 277 202 374 105 374 105 277" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0" /><text x="21" y="380" fill="yellow">Ruler</text><polygon points=" 21 380  47 380  47 391  21 391  21 380" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>
